# %%
#import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,root_mean_squared_error

# %%
#TASK1#
#LOAD THE DATASET INTO PYTHON NOTEBOOK AND IMPOER REQUIRED LIBRARIES AND DESCRIBE DATA TO EXPLORE

# %%
df=pd.read_csv(r'Downloads/DS1_C9_S3_Practice_MedicalPremium_Data.csv')
df
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Diabetes', 'BloodPressureProblems', 'AnyTransplants',
#        'AnyChronicDiseases', 'Height', 'Weight', 'KnownAllergies',
#        'HistoryOfCancerInFamily', 'NumberOfMajorSurgeries', 'PremiumPrice'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    int64
#  2   BloodPressureProblems    986 non-null    int64
#  3   AnyTransplants           986 non-null    int64
#  4   AnyChronicDiseases       986 non-null    int64
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    int64
#  8   HistoryOfCancerInFamily  986 non-null    int64
#  9   NumberOfMajorSurgeries   986 non-null    int64
#  10  PremiumPrice             986 non-null    int64
# dtypes: int64(11)
# memory usage: 84.9 KB

# %%
df.head()
# Out:
#    Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0   45         0                      0               0                   0
# 1   60         1                      0               0                   0
# 2   36         1                      1               0                   0
# 3   52         1                      1               0                   1
# 4   38         0                      0               0                   1
#
#    Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0     155      57               0                        0
# 1     180      73               0                        0
# 2     158      59               0                        0
# 3     183      93               0                        0
# 4     166      88               0                        0
#
#    NumberOfMajorSurgeries  PremiumPrice
# 0                       0         25000
# 1                       0         29000
# ...

# %%
df.describe()
# Out:
#               Age    Diabetes  BloodPressureProblems  AnyTransplants  \
# count  986.000000  986.000000             986.000000      986.000000
# mean    41.745436    0.419878               0.468560        0.055781
# std     13.963371    0.493789               0.499264        0.229615
# min     18.000000    0.000000               0.000000        0.000000
# 25%     30.000000    0.000000               0.000000        0.000000
# 50%     42.000000    0.000000               0.000000        0.000000
# 75%     53.000000    1.000000               1.000000        0.000000
# max     66.000000    1.000000               1.000000        1.000000
#
#        AnyChronicDiseases      Height      Weight  KnownAllergies  \
# count          986.000000  986.000000  986.000000      986.000000
# mean             0.180527  168.182556   76.950304        0.215010
# std              0.384821   10.098155   14.265096        0.411038
# min              0.000000  145.000000   51.000000        0.000000
# ...

# %%
df.dtypes
# Out:
# Age                        int64
# Diabetes                   int64
# BloodPressureProblems      int64
# AnyTransplants             int64
# AnyChronicDiseases         int64
# Height                     int64
# Weight                     int64
# KnownAllergies             int64
# HistoryOfCancerInFamily    int64
# NumberOfMajorSurgeries     int64
# PremiumPrice               int64
# dtype: object

# %%
#TASK2#
#Clean the data through missing value and outlier treatments.

# %%
df.isnull().sum()
# Out:
# Age                        0
# Diabetes                   0
# BloodPressureProblems      0
# AnyTransplants             0
# AnyChronicDiseases         0
# Height                     0
# Weight                     0
# KnownAllergies             0
# HistoryOfCancerInFamily    0
# NumberOfMajorSurgeries     0
# PremiumPrice               0
# dtype: int64

# %%
# Identified outliers for all the columns:
def outliers(df):
    for col in df.select_dtypes(include=['number']).columns:
        q1=df[col].quantile(0.25)
        q3=df[col].quantile(0.75)
        IQR=q3-q1
        LF=q1-1.5*IQR
        UF=q3+1.5*IQR
        outlier=df[(df[col]<LF) | (df[col]>UF)]
    return outlier

# call
alloutlier=outliers(df)
alloutlier
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 204   27         0                      1               0                   0
# 295   64         1                      1               0                   1
# 926   24         0                      1               0                   0
# 928   19         0                      0               0                   0
# 976   21         0                      1               0                   0
# 984   47         1                      1               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 204     159     120               1                        1
# 295     163      91               0                        0
# 926     159      67               0                        0
# 928     171      67               0                        0
# 976     155      74               0                        0
# ...

# %%
# Removed outliers for all the columns:
def remove_outliers(df):
    for col in df.select_dtypes(include=['number']).columns:
        q1=df[col].quantile(0.25)
        q3=df[col].quantile(0.75)
        IQR=q3-q1
        LF=q1-1.5*IQR
        UF=q3+1.5*IQR
        outlier_removal=df[(df[col]>=LF) & (df[col]<=UF)]
    return outlier_removal
alloutlier=remove_outliers(df)
df
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 980   40         0                      1               1                   0
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 985   21         0                      0               0                   0
#
# ...

# %%
#Perform data pre-processing to prepare the data for further processes such as data scaling.

# %%
preprocessing.LabelEncoder()

# %%
sc=preprocessing.StandardScaler()
data=pd.DataFrame(sc.fit_transform(df),columns=df.columns)
data
# Out:
#           Age  Diabetes  BloodPressureProblems  AnyTransplants  \
# 0    0.230158 -0.851676              -0.934775       -0.243843
# 1    1.307305  1.174155              -0.934775       -0.243843
# 2   -0.416131  1.174155               1.069776       -0.243843
# 3    0.732827  1.174155               1.069776       -0.243843
# 4   -0.272511 -0.851676              -0.934775       -0.243843
# ..        ...       ...                    ...             ...
# 975 -0.128891 -0.851676               1.069776        4.100998
# 976 -1.708708 -0.851676              -0.934775       -0.243843
# 977  1.594545  1.174155               1.069776       -0.243843
# 978  1.020066 -0.851676               1.069776       -0.243843
# 979 -1.493278 -0.851676              -0.934775       -0.243843
#
#      AnyChronicDiseases    Height    Weight  KnownAllergies  \
# 0             -0.469493 -1.309721 -1.400792       -0.522233
# 1             -0.469493  1.165645 -0.275623       -0.522233
# ...

# %%
#Check the assumption for the existence of multicollinearity among independent features. Select cut-off value as 0.7.

# %%
plt.figure(figsize=(12, 10))
sb.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
#Calculate the correlation coefficients between all independent features and "PremiumPrice". Identify the features with the highest correlation values.

# %%
# Calculate correlation coefficients between independent features and 'PremiumPrice'
df1 = df.corr()['PremiumPrice']
df1
#PREMIUM PROCE HAS HIGHEST CORRELATION
# Out:
# Age                        0.721895
# Diabetes                   0.080163
# BloodPressureProblems      0.159722
# AnyTransplants             0.297832
# AnyChronicDiseases         0.213095
# Height                     0.038217
# Weight                     0.139465
# KnownAllergies             0.008225
# HistoryOfCancerInFamily    0.082792
# NumberOfMajorSurgeries     0.266121
# PremiumPrice               1.000000
# Name: PremiumPrice, dtype: float64

# %%
#Task 3

#Build and evaluate linear regression models with increasing numbers of features (1, 2, and 3) based on their correlation with the target variable "PremiumPrice". Choose the best model with 3 features for prediction.

#For each model (1, 2, and 3 features):

#Select the top N features (N being 1, 2, or 3) with the highest correlation values with "PremiumPrice".

#Task 3 (cont'd)

# Build a linear regression model using the selected features.
#Extract and display the intercept and slope coefficients
#Evaluate the model performance using MSE, RMSE, MAE, and R-squared values.

# %%
X=data.loc[:,['Age','AnyTransplants','AnyChronicDiseases']]
Y=data[['PremiumPrice']]
X
Y
# Out:
#      PremiumPrice
# 0        0.122516
# 1        0.772400
# 2       -0.202425
# 3        0.609929
# 4       -0.202425
# ..            ...
# 975      2.234638
# 976     -1.502192
# 977      0.609929
# 978      0.772400
# 979     -1.502192
#
# [980 rows x 1 columns]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=.30,random_state=41)
LM=LinearRegression()
LM.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
LM.coef_
# Out:
# array([[0.7130018 , 0.28934595, 0.17564624]])

# %%
LM.intercept_
# Out:
# array([0.00086689])

# %%
X.columns
# Out:
# Index(['Age', 'AnyTransplants', 'AnyChronicDiseases'], dtype='object')

# %%
b1=LM.coef_[0,0]
b2=LM.coef_[0,1]
b3=LM.coef_[0,2]
a=LM.intercept_
y=a+b1*.20+b2*.25+b3*20
y
# Out:
# array([3.72872859])

# %%
#Task 3 (cont'd)

# Build a linear regression model using the selected features.
#Extract and display the intercept and slope coefficients
#Evaluate the model performance using MSE, RMSE, MAE, and R-squared values.

# %%
prediction=LM.predict(X_test)
r2_score(prediction,Y_test)
# Out:
# 0.4402236936820262

# %%
mean_absolute_error(prediction,Y_test)
# Out:
# 0.4475840048309501

# %%
mean_squared_error(prediction,Y_test)
# Out:
# 0.3536289875722437

# %%
root_mean_squared_error(prediction,Y_test)
# Out:
# 0.5946671233322418

# %%
#Task 4

#Model Selection:

#Compare the evaluation metrics (MSE, RMSE, MAE, R-squared) across all models

#Choose the model with the best overall performance as the best model with 3 features for prediction

# %%
mse = mean_squared_error(prediction,Y_test)
rmse = np.sqrt(mse)
mae = mean_absolute_error(prediction,Y_test)
r2= r2_score(prediction,Y_test)

print("Model Evaluation Metrics:")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R² Score: {r2}")
# Out:
# Model Evaluation Metrics:
# Mean Squared Error (MSE): 0.3536289875722437
# Root Mean Squared Error (RMSE): 0.5946671233322418
# Mean Absolute Error (MAE): 0.4475840048309501
# R² Score: 0.4402236936820262

# %%
#Task 5

#Present the residual plot and error distribution plot to check whether the model meets the assumption of homoscedasticity and errors are normally distributed''

# %%
x1=X.iloc[:,0]
x2=X.iloc[:,1]
x3=X.iloc[:,2]
y=data[[ 'PremiumPrice']]

# %%
fig=plt.subplots(figsize=(12,8))
ax=plt.axes(projection='3d')
ax.grid(b=True,color='grey',linestyle='-',alpha=0.2)
ax.scatter3D(x1,x2,y)
ax.set_xlabel('Age,AnyTransplants')
ax.set_ylabel('AnyChronicDiseases')
ax.set_zlabel('PremiumPrice')
plt.show()

# %%
#Task 6

#Write the overall interpretation of the model performance from all the above evaluation parameters and assumptions.

#Define the final equation of the linear regression model.'''

# %%
Interpretation:
MSE (0.35), RMSE (0.594, and MAE (0.44) indicate that the model’s predictions are close to the actual values with reasonable accuracy.
The R² score (0.4402) means that around 44% of the variance in Premium Price is explained by the model, and states that there’s room for improvement.

# %%
# Linear Regression Equation
# PremiumPrice = β0 + β1 * Age + β2 * AnyTransplants + β3 * AnyChronicDiseases
# Where: β0, β1, β2, β3 are the coefficients from the model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv(r"DS1_C5_S1_EmployeeAttrition_Data_Practice.csv")
df
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 0     41.0       Yes      Travel_Rarely                   Sales
# 1     49.0        No  Travel_Frequently  Research & Development
# 2     37.0       Yes      Travel_Rarely  Research & Development
# 3     33.0        No  Travel_Frequently  Research & Development
# 4     27.0        No      Travel_Rarely  Research & Development
# ...    ...       ...                ...                     ...
# 1465  36.0        No                NaN  Research & Development
# 1466  39.0        No      Travel_Rarely  Research & Development
# 1467  27.0        No      Travel_Rarely  Research & Development
# 1468  49.0        No  Travel_Frequently                   Sales
# 1469  34.0        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome EducationField  EmployeeNumber  \
# 0                    1  Life Sciences               1
# 1                    8  Life Sciences               2
# ...

# %%
#TASK1:
df.columns   #column names
df.notnull().sum() #non null records
df.dtypes  #types of columns
df.isnull().sum() #missing value

# %%
#TASK2
df.select_dtypes(include='object').dtypes
# Out:
# Attrition         object
# BusinessTravel    object
# Department        object
# EducationField    object
# Gender            object
# JobRole           object
# MaritalStatus     object
# Over18            object
# OverTime          object
# dtype: object

# %%
df.select_dtypes(exclude='object').dtypes
# Out:
# Age                         float64
# DistanceFromHome              int64
# EmployeeNumber                int64
# EnvironmentSatisfaction       int64
# HourlyRate                    int64
# JobInvolvement                int64
# JobSatisfaction               int64
# MonthlyIncome                 int64
# NumCompaniesWorked            int64
# PerformanceRating             int64
# RelationshipSatisfaction      int64
# TotalWorkingYears             int64
# TrainingTimesLastYear         int64
# WorkLifeBalance               int64
# YearsAtCompany                int64
# YearsInCurrentRole            int64
# YearsSinceLastPromotion       int64
# YearsWithCurrManager          int64
# dtype: object

# %%
num=[]
cat=[]
def select_dtype(col):
    if df[col].nunique()>20:
        num.append(col)
    else:
        cat.append(col)

# %%
num
# Out:
# ['Age',
#  'DistanceFromHome',
#  'EmployeeNumber',
#  'HourlyRate',
#  'MonthlyIncome',
#  'TotalWorkingYears',
#  'YearsAtCompany']

# %%
cat
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'JobInvolvement',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'NumCompaniesWorked',
#  'Over18',
#  'OverTime',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
for col in df.columns:
    select_dtype(col)

# %%
#TASK3
import pandas as pd
def task3(df, cat):
    for col in cat:
        print(f"column name is: {col}")
        print(f"Number of Unique Categories in column: {df[col].nunique()}")
        print(f"Mode: {df[col].mode()[0]}")
        print(f"Missing Values: {df[col].isnull().sum()}\n")
task3(df, cat)

# %%
#TASK4
num_df=df.loc[:,num]
num_df
# Out:
#        Age  DistanceFromHome  EmployeeNumber  HourlyRate  MonthlyIncome  \
# 0     41.0                 1               1          94           5993
# 1     49.0                 8               2          61           5130
# 2     37.0                 2               4          92           2090
# 3     33.0                 3               5          56           2909
# 4     27.0                 2               7          40           3468
# ...    ...               ...             ...         ...            ...
# 1465  36.0                23            2061          41           2571
# 1466  39.0                 6            2062          42           9991
# 1467  27.0                 4            2064          87           6142
# 1468  49.0                 2            2065          63           5390
# 1469  34.0                 8            2068          82           4404
#
#       TotalWorkingYears  YearsAtCompany
# 0                     8               6
# ...

# %%
cat_df=df.loc[:,cat]
cat_df
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No                NaN  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       EnvironmentSatisfaction  Gender  JobInvolvement  \
# ...

# %%
sb.countplot(data=cat_df,x='Attrition')

# %%
plt.pie(x=cat_df['Attrition'].value_counts().values,labels=cat_df['Attrition'].value_counts().index,autopct='%.2f%%')

# %%
sb.countplot(data=cat_df,x='BusinessTravel')

# %%
plt.pie(x=cat_df['BusinessTravel'].value_counts().values,labels=cat_df['BusinessTravel'].value_counts().index,autopct='%.2f%%')

# %%
#TASK4(CONT'D)
sb.countplot(data=cat_df,x='Department')

# %%
plt.pie(x=cat_df['Department'].value_counts().values,labels=cat_df['Department'].value_counts().index,autopct='%.2f%%')

# %%
sb.countplot(data=cat_df,x='EducationField')

# %%
plt.pie(x=cat_df['EducationField'].value_counts().values,labels=cat_df['EducationField'].value_counts().index,autopct='%.2f%%')

# %%
sb.countplot(data=cat_df,x='EnvironmentSatisfaction')

# %%
plt.pie(x=cat_df['EnvironmentSatisfaction'].value_counts().values,labels=cat_df['EnvironmentSatisfaction'].value_counts().index,autopct='%.2f%%')

# %%
sb.countplot(data=cat_df,x='Gender')

# %%
plt.pie(x=cat_df['Gender'].value_counts().values,labels=cat_df['Gender'].value_counts().index,autopct='%.2f%%')

# %%
sb.countplot(data=cat_df,x='MaritalStatus')

# %%
plt.pie(x=cat_df['MaritalStatus'].value_counts().values,labels=cat_df['MaritalStatus'].value_counts().index,autopct='%.2f%%')

# %%
plt.pie(x=cat_df['OverTime'].value_counts().values,labels=cat_df['OverTime'].value_counts().index,autopct='%.2f%%')

# %%
plt.pie(x=cat_df['PerformanceRating'].value_counts().values,labels=cat_df['PerformanceRating'].value_counts().index,autopct='%.2f%%')

# %%
plt.pie(x=cat_df['WorkLifeBalance'].value_counts().values,labels=cat_df['WorkLifeBalance'].value_counts().index,autopct='%.2f%%')

# %%
#TASK5
import pandas as pd
def task5(df, num):
    for col in num:
        print(f"Analysis of Column: {col}")
        print(f"Mean: {df[col].mean():.2f}")
        print(f"Median: {df[col].median():.2f}")
        print(f"Standard Deviation: {df[col].std():.2f}")
        print(f"Missing Values: {df[col].isnull().sum()}")
        print(f"Skewness: {df[col].skew():.2f}")
        if df[col].isnull().sum() > 0:
            median_value = df[col].median()
            df[col].fillna(median_value, inplace=True)
            print(f"Filled missing values with median: {median_value}\n")
        else:
            print("No missing values.\n")

task5(df, num)

# %%
#TASK6

sb.histplot(data=num_df, x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sb.boxplot(data=num_df, x='Age')

# %%
sb.histplot(data=num_df, x='HourlyRate')

# %%
sb.boxplot(data=num_df, x='HourlyRate')

# %%
sb.histplot(data=num_df, x='MonthlyIncome')

# %%
sb.boxplot(data=num_df, x='MonthlyIncome')

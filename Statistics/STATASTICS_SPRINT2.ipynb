# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import scipy.stats as st
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"Downloads/DS1_C8_S2_SmartCarRiding_Data_Practice.csv")
df
# Out:
#            Index      key  fare_amount          pickup_datetime  \
# 0       24238194  52:06.0          7.5  2015-05-07 19:52:06 UTC
# 1       27835199  04:56.0          7.7  2009-07-17 20:04:56 UTC
# 2       44984355  45:00.0         12.9  2009-08-24 21:45:00 UTC
# 3       25894730  22:21.0          5.3  2009-06-26 08:22:21 UTC
# 4       17610152  47:00.0         16.0  2014-08-28 17:47:00 UTC
# ...          ...      ...          ...                      ...
# 199995  42598914  49:00.0          3.0  2012-10-28 10:49:00 UTC
# 199996  16382965  09:00.0          7.5  2014-03-14 01:09:00 UTC
# 199997  27804658  42:00.0         30.9  2009-06-29 00:42:00 UTC
# 199998  20259894  56:25.0         14.5  2015-05-20 14:56:25 UTC
# 199999  11951496  08:00.0         14.1  2010-05-15 04:08:00 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             -73.999817        40.738354         -73.999512
# 1             -73.994355        40.728225         -73.994710
# ...

# %%
#TASK1
df.shape
# Out:
# (200000, 9)

# %%
df.columns
# Out:
# Index(['Index', 'key', 'fare_amount', 'pickup_datetime', 'pickup_longitude',
#        'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude',
#        'passenger_count'],
#       dtype='object')

# %%
df.fare_amount
# Out:
# 0          7.5
# 1          7.7
# 2         12.9
# 3          5.3
# 4         16.0
#           ...
# 199995     3.0
# 199996     7.5
# 199997    30.9
# 199998    14.5
# 199999    14.1
# Name: fare_amount, Length: 200000, dtype: float64

# %%
#TASK2 PERFORM OUTLIER TREAMENT ON FARE AMOUNT

# %%
plt.boxplot([df['fare_amount']],labels=['fare_amount'])
plt.show()

# %%
Q1 = df['fare_amount'].quantile(0.25)
Q3 = df['fare_amount'].quantile(0.75)
IQR = Q3 - Q1
lower_frence = Q1 - 1.5 * IQR
upper_frence = Q3 + 1.5 * IQR
df = df[(df['fare_amount'] >= lower_frence) & (df['fare_amount'] <= upper_frence)]
print(df.fare_amount)
# Out:
# 0          7.5
# 1          7.7
# 2         12.9
# 3          5.3
# 4         16.0
#           ...
# 199994    12.0
# 199995     3.0
# 199996     7.5
# 199998    14.5
# 199999    14.1
# Name: fare_amount, Length: 177105, dtype: float64

# %%
plt.boxplot([df['fare_amount']],labels=['fare_amount'])
plt.show()

# %%
#TASK3 Draw different distribution plots for the following sample sizes:
#10, 15, 30, 200, 1000, 5000, 10000, 50000, 100000.
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
fare_data = df['fare_amount']
sample_sizes = [10, 15, 30, 200, 1000, 5000, 10000, 50000, 100000]
plt.figure(figsize=(16, 12))
for i, size in enumerate(sample_sizes,start=1):
    sample = fare_data.sample(size, random_state=1, replace=True) 
    plt.subplot(3, 3, i)
    sns.histplot(sample, kde=True, bins=30, color='blue', edgecolor='black')
    plt.title(f"Sample Size: {size}")
    plt.xlabel("Fare Amount")
    plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
#TASK4 Extract sample data using the random sampling with replacement technique. Ensure the sample size is greater than or equal to 200.
df.sample(200,replace=False,random_state=1).sort_index
# Out:
# <bound method DataFrame.sort_index of            Index      key  fare_amount          pickup_datetime  \
# 13892   14681746  12:00.0          6.5  2013-10-18 15:12:00 UTC
# 120978  35946749  06:00.0          7.5  2014-03-16 11:06:00 UTC
# 133690  52638190  19:00.0          9.5  2014-05-21 19:19:00 UTC
# 159047  38035790  25:47.0          6.0  2014-12-08 19:25:47 UTC
# 98319   29242439  52:00.0          8.9  2011-07-05 20:52:00 UTC
# ...          ...      ...          ...                      ...
# 92231   19165127  01:47.0          4.5  2011-04-12 08:01:47 UTC
# 25402   22563048  44:00.0         14.9  2011-12-03 15:44:00 UTC
# 166884  51155448  16:45.0          8.1  2011-05-26 13:16:45 UTC
# 39722   46911066  46:00.0          7.7  2011-12-10 09:46:00 UTC
# 46311    4039705  22:00.0          6.9  2010-01-30 00:22:00 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 13892         -73.987460        40.744235         -74.000497
# ...

# %%
#TASK5
df1= [df['fare_amount'].mean(),
df['fare_amount'].median(),
df['fare_amount'].mode()[0],
df['fare_amount'].std(),
st.skew(df['fare_amount']),
st.kurtosis(df['fare_amount'])]

# %%
s200=df.sample(n=200)
sb.histplot(s200['fare_amount'],kde=True)
# Out:
# <Axes: xlabel='fare_amount', ylabel='Count'>

# %%
S200= [s200['fare_amount'].mean(),
s200['fare_amount'].median(),
s200['fare_amount'].mode()[0],
s200['fare_amount'].std(),
st.skew(df['fare_amount']),
st.kurtosis(df['fare_amount'])]

# %%
df2=pd.DataFrame()
df2['Measure']=['Mean','Median','Mode','std','Skew','Kurt.']
df2['Population']=df1
df2['s-200']=S200

# %%
df2
# Out:
#   Measure  Population      s-200
# 0    Mean   11.359955  12.076850
# 1  Median    8.500000   8.100000
# 2    Mode    6.500000   6.500000
# 3     std    9.901776  12.564655
# 4    Skew    4.504813   4.504813
# 5   Kurt.   63.882687  63.882687

# %%
Mean: The sample mean 12.08 is   close to the population mean 11.36, supporting the central limit .
Median and Mode: These values are close and consistent between the entire data  and the sample.

Standard Deviation: The sample standard deviation 12.56 is slightly higher.
Skewness and Kurtosis: Both values are samel for entire data and sample.

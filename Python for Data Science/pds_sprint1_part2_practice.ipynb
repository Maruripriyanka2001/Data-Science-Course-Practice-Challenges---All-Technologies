# %%
#DATA DICTIONARY
#TASK1:FIND TOTAL NUMBER OF COLUMNS AND ROWS
import numpy as np
data=np.genfromtxt('task1.csv',delimiter=',',skip_header=1)
data.shape
# Out:
# (400, 9)

# %%
#TASK2: DISPLAY GRE SCORE OF ALL STUDENTS
print(data[:,1])
# Out:
# [337. 324. 316. 322. 314. 330. 321. 308. 302. 323. 325. 327. 328. 307.
#  311. 314. 317. 319. 318. 303. 312. 325. 328. 334. 336. 340. 322. 298.
#  295. 310. 300. 327. 338. 340. 331. 320. 299. 300. 304. 307. 308. 316.
#  313. 332. 326. 322. 329. 339. 321. 327. 313. 312. 334. 324. 322. 320.
#  316. 298. 300. 311. 309. 307. 304. 315. 325. 325. 327. 316. 318. 328.
#  332. 336. 321. 314. 314. 329. 327. 301. 296. 294. 312. 340. 320. 322.
#  340. 319. 315. 317. 314. 316. 318. 299. 298. 301. 303. 304. 306. 331.
#  332. 323. 322. 312. 314. 317. 326. 316. 329. 338. 331. 304. 305. 321.
#  301. 320. 311. 310. 299. 290. 296. 327. 335. 334. 310. 308. 301. 300.
#  323. 319. 326. 333. 339. 303. 309. 323. 333. 314. 312. 316. 326. 318.
#  329. 332. 331. 340. 325. 320. 315. 326. 339. 311. 334. 332. 321. 324.
#  326. 312. 315. 309. 306. 297. 315. 298. 318. 317. 329. 322. 302. 313.
#  293. 311. 312. 334. 322. 323. 321. 320. 329. 319. 309. 307. 300. 305.
# ...

# %%
#TASK3 FIND TOTAL SUDENT WHO HAVE SCORED GREATER THAN 320
total_students = np.sum(data[:, 1] > 320)
print(total_students)
# Out:
# 163

# %%
#TASK4:DISPLAY RECORDS OF TOFEL WHO SCORE GREATER THAN 110 AND DSIPLAY CHANCE OF ADMISSION AS PERCENTAGE NUMBER BY MULTIPLYING EACH VALUE IN OUTPUT BY 100
arr=(data[:, 2][data[:, 2] > 110])
ar =(data[:, 8][data[:, 2] > 110] * 100)
print("Admission chances as percentages:", ar)
index_locations = np.where(data[:, 2] > 110)[0]
print("Index locations:", index_locations)
# Out:
# Admission chances as percentages: [92. 90. 84. 78. 70. 94. 95. 97. 94. 91. 90. 94. 87. 91. 86. 89. 78. 78.
#  72. 52. 55. 61. 78. 94. 96. 93. 72. 74. 96. 92. 94. 86. 90. 79. 74. 87.
#  91. 93. 94. 94. 85. 78. 84. 92. 96. 79. 89. 80. 90. 92. 97. 80. 81. 83.
#  96. 93. 94. 86. 81. 89. 89. 87. 85. 90. 89. 93. 93. 88. 90. 86. 94. 97.
#  97. 95. 96. 94. 93. 91. 76. 71. 82. 91. 88. 85. 86. 70. 76. 77. 93. 85.
#  90. 70. 83. 89. 80. 94. 93. 92. 89. 86. 90. 71. 80. 79. 80. 81. 80. 80.
#  83. 94. 93. 91. 86. 95. 96. 96. 84. 89. 91. 95.]
# Index locations: [  0   5  11  12  21  22  23  24  25  32  33  34  43  44  46  47  49  52
#   53  64  65  66  69  70  71  72  75  76  81  83  84  97  98  99 104 106
#  107 108 120 121 126 127 128 129 130 133 134 138 141 142 143 144 145 147
#  148 150 151 152 164 171 173 174 175 176 185 187 188 189 190 192 193 202
#  203 212 213 214 215 216 222 228 229 234 235 236 237 242 243 249 253 254
# ...

# %%
#TASK5:finded the index location of students who are 
arr1= data[(data[:, 2] > 115) & (data[:, 1] > 315)]
index_locations = np.where((data[:, 2] > 115) & (data[:, 1] > 315))[0]
print("Index locations :", index_locations)
# Out:
# Index locations : [  0  22  23  24  25  32  43  47  52  70  81  97  98 107 108 120 121 129
#  138 141 143 148 151 171 176 187 193 202 203 212 213 214 215 259 285 286
#  297 325 337 361 372 385 397 399]
